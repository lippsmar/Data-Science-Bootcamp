# %% [markdown]
# So far we've learnt how to scrape the web, and how to make a request for information from an API. Some websites make APIs even easier. Check out [RapidAPI](https://rapidapi.com/) they take care of writing most of the code for you.
#
# We will use the [AeroDataBox API](https://rapidapi.com/aedbx-aedbx/api/aerodatabox/), which can retrieve all sorts of information about flights and airports. We will show you how to retrieve information about the airports, and then it's up to you to apply this, along with what you've already learnt this week, to **produce a function, which retrieves tomorrows flight information for the major airports in the cities you web scraped**.

# %%
import pandas as pd
import requests

# %% [markdown]
# On the left hand side of the AeroDataBox API page, you'll see a list of options for information that you can retrieve:
# > - Flights API
# - Subsciption / PUSH API
# - Airport API
# - Aircraft API
# - Healthcheck & Status API
#
# 1. We want to select `Airport API`
#
# 2. Then within Airport API we want to select `Search airports by location`
#
# 3. Now in the middle third you'll want to enter the `latitude` and `longitude` of any city to test... we chose Berlin: latitude 52.31 longitude 13.24. Next we changed the `radiusKM` to only 50km. And finally set `withFlightInfoOnly` to true, so it will only return airports which have flight data (scheduled or live) available.
#
# 4. On the right hand third of the screen you should see a block of code that looks pretty unfamiliar. This is because by default the code is probably set to *(Node.js) Axios*. However, we have the power to change this to familiar python. Select the dropdown box at the top of the code and select `python > requests`.
#
# Now you can copy the code to your notebook and it should look a little something like the cell below:

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/airports/search/location/52.31/13.24/km/50/10"

querystring = {"withFlightInfoOnly":"true"}

headers = {
	"X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4", #"YOUR_API_KEY_HERE",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"searchBy":{"lat":52.31,"lon":13.24},"count":1,"items":[{"icao":"EDDB","iata":"BER","name":"Berlin Brandenburg","shortName":"Brandenburg","municipalityName":"Berlin","location":{"lat":52.35139,"lon":13.493889},"countryCode":"DE"}]}

# %% [markdown]
# Let's view the response as `.json()` instead of `.text` so that it's easier to read

# %%
response.json()
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE'}]}

# %% [markdown]
# We can now turn this into a dataframe using `.json_normalize()`

# %%
pd.json_normalize(response.json()['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#    location.lat  location.lon
# 0      52.35139     13.493889

# %% [markdown]
# Let's now use this for the latitude and longitude of multiple cities

# %%
def icao_airport_codes(latitudes, longitudes):

  #assert len(latitudes) == len(longitudes)

  list_for_df = []

  for index, value in enumerate(latitudes):

    url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{value}/{longitudes[index]}/km/50/10"

    querystring = {"withFlightInfoOnly":"true"}

    headers = {
      "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
      "X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)

    list_for_df.append(pd.json_normalize(response.json()['items']))

  return pd.concat(list_for_df, ignore_index=True)

# %%
icao_airport_codes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 icao_airport_codes()
#
# TypeError: icao_airport_codes() missing 2 required positional arguments: 'latitudes' and 'longitudes'

# %%
latitudes
# Out:
# [52.52, 48.8567, 51.5072]

# %%
list_for_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 list_for_df
#
# NameError: name 'list_for_df' is not defined

# %%
list(enumerate(latitudes))
# Out:
# [(0, 52.52), (1, 48.8567), (2, 51.5072)]

# %%
# coordinates for Berlin, Paris, London
latitudes = [52.5200, 48.8567, 51.5072]
longitudes = [13.4050, 2.3522, -0.1275]

#icao_airport_codes(latitudes, longitudes)

# %%
def push_airport_data_to_sql():

  #assert len(latitudes) == len(longitudes)
    
    import pandas as pd
    import requests
    from sqlalchemy import create_engine, inspect

    schema = "gans"
    host = "127.0.0.1"
    user = "root"
    password = "MySQLjau"
    port = 3306
    connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

    
    latitudes = (pd.read_sql("cities", con=connection_string))["lat"]
    longitudes = (pd.read_sql("cities", con=connection_string))["lon"]

    list_for_df = []

    for index, value in enumerate(latitudes):

        url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{value}/{longitudes[index]}/km/50/10"

        querystring = {"withFlightInfoOnly":"true"}

        headers = {
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
        "X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"
        }

        response = requests.request("GET", url, headers=headers, params=querystring)

        list_for_df.append(pd.json_normalize(response.json()['items']))

        airports_df = pd.concat(list_for_df, ignore_index=True)

        engine = create_engine(connection_string)
        inspector = inspect(engine)
        if 'airports' in inspector.get_table_names():
          existing_data = pd.read_sql('airports', engine)
          airports_df = airports_df[~airports_df['iata'].isin(existing_data['iata'])]

        airports_df.to_sql('airports',
                  if_exists='append',
                  con=connection_string,
                  index=False)

    return airports_df

# %%
push_airport_data_to_sql()
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 3  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#    location.lat  location.lon
# 3      52.35139     13.493889

# %% [markdown]
# ###### **Challenge:** Arrivals information
# Using what you have been shown above, plus the skills you've learnt in the last couple of days:
# 1. In `AeroDataBox API` use the `Flight API` > `FIDS/Schedules: Airport departures and arrivals by airport ICAO code` section
# 2. Fill out the parameters in the middle third and then copy the `python: requests` code from the right hand third
# 3. Explore the data you get back. What would be useful in your DataFrame and what can be excluded? Remember Gans wants to know about when people are arriving in the city
# 4. Make a DataFrame from the information you see as important
# 5. Condense everything you did above into a function that can take a list of ICAO codes as an input, and as an output gives you a DataFrame with the information for *tomorrows arrivals*

# %%
def push_cities_airports_to_sql():

    import pandas as pd
    from sqlalchemy import create_engine, inspect
    

    schema = "gans"
    host = "127.0.0.1"
    user = "root"
    password = "MySQLjau"
    port = 3306
    connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

    cities_df = pd.read_sql("cities", con=connection_string)
    airports_df = pd.read_sql("airports", con=connection_string)

    cities_airports_df = (pd.merge(cities_df, airports_df, left_on="city", right_on="municipalityName", how="left"))[["city_id","iata"]]
    cities_airports_df

    engine = create_engine(connection_string)
    inspector = inspect(engine)
    if 'cities_airports' in inspector.get_table_names():
        existing_data = pd.read_sql('cities_airports', engine)
        cities_airports_df = cities_airports_df[~cities_airports_df['city_id'].isin(existing_data['city_id'])]

    cities_airports_df.to_sql('cities_airports',
            if_exists='append',
            con=connection_string,
            index=False)
    
    return cities_airports_df

# %%
push_cities_airports_to_sql()
# Out:
#    city_id iata
# 0  2867714  MUC
# 1  2911298  HAM
# 2  2944388  BRE
# 3  2950159  BER

# %%
import requests
from datetime import datetime, timedelta
from sqlalchemy import create_engine, inspect

schema = "gans"
host = "127.0.0.1"
user = "root"
password = "MySQLjau"
port = 3306
connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

iata_list = (pd.read_sql("cities_airports", con=connection_string))["iata"]
current_time = datetime.now()
start_time = current_time.strftime("%Y-%m-%dT%H:%M")
end_time = (current_time + timedelta(hours=12)).strftime("%Y-%m-%dT%H:%M")

querystring = {"withLeg":"false","direction":"Arrival","withCancelled":"false","withCodeshared":"false", "withCargo":"false","withPrivate":"false","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

flights_dict = {
	"flight_num": [],
	"departure_iata": [], 
	"arrival_iata": [], 
	"arrival_time": []}

for iata in iata_list:
    
	url = f"https://aerodatabox.p.rapidapi.com/flights/airports/iata/{iata}/{start_time}/{end_time}"
	flight_data_raw = requests.get(url, headers=headers, params=querystring).json()

	for arrival in flight_data_raw["arrivals"]:
		departure_iata = arrival["movement"]["airport"].get("iata", "Unknown")
		arrival_time = arrival["movement"].get("revisedTime", {}).get("local") or arrival["movement"]["scheduledTime"]["local"]
		flights_dict["flight_num"].append(arrival["number"])
		flights_dict["departure_iata"].append(departure_iata)
		flights_dict["arrival_iata"].append(iata)
		flights_dict["arrival_time"].append(datetime.strptime(arrival_time, "%Y-%m-%d %H:%M%z").strftime("%Y-%m-%d %H:%M:%S"))

flights_df = pd.DataFrame(flights_dict)

engine = create_engine(connection_string)
inspector = inspect(engine)

if 'flights' in inspector.get_table_names():
	existing_data = pd.read_sql('flights', engine)
	flights_df = flights_df[~flights_df['flight_num'].isin(existing_data['flight_num'])]

flights_df.to_sql('flights',
				con=engine,
				if_exists='append',
				index=False
				)
# Out:
# 152

# %%
flights_df.dtypes
# Out:
# flight_num        object
# departure_iata    object
# arrival_iata      object
# arrival_time      object
# dtype: object

# %%
from datetime import datetime
datetime.strptime(flight_data_raw["arrivals"][0]["movement"]["revisedTime"]["local"], "%Y-%m-%d %H:%M%z").strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2024-03-11 08:02:00'

# %%
flight_data_raw
# Out:
# {'arrivals': [{'movement': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:02Z',
#      'local': '2024-03-11 08:02+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9048',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 08:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:03Z',
#      'local': '2024-03-11 08:03+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:09Z',
#      'local': '2024-03-11 08:09+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKP', 'modeS': '461E1F', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'movement': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 52FP',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 07:35Z',
#      'local': '2024-03-11 08:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:06Z',
#      'local': '2024-03-11 08:06+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:07Z',
#      'local': '2024-03-11 08:07+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 111',
#    'callSign': 'RYR81QP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EBC', 'modeS': '4CA700', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:08Z',
#      'local': '2024-03-11 08:08+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 211',
#    'callSign': 'BTI74A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSK',
#     'modeS': '502CE5',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#   {'movement': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'scheduledTime': {'utc': '2024-03-11 07:30Z',
#      'local': '2024-03-11 08:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:14Z',
#      'local': '2024-03-11 08:14+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA223',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LZD', 'modeS': '440605', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'movement': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:16Z',
#      'local': '2024-03-11 08:16+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4873',
#    'callSign': 'EJU40FD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICK', 'modeS': '440053', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LOWG', 'iata': 'GRZ', 'name': 'Graz'},
#     'scheduledTime': {'utc': '2024-03-11 07:40Z',
#      'local': '2024-03-11 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:26Z',
#      'local': '2024-03-11 08:26+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8347',
#    'callSign': 'EWG2KA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EUW', 'modeS': '4D240E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'LYBE', 'iata': 'BEG', 'name': 'Belgrade'},
#     'scheduledTime': {'utc': '2024-03-11 08:00Z',
#      'local': '2024-03-11 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:40Z',
#      'local': '2024-03-11 08:40+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'JA 350',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LY-LOC', 'modeS': '503CC0', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 07:55Z',
#      'local': '2024-03-11 08:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:48Z',
#      'local': '2024-03-11 08:48+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH7EE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZZ',
#     'modeS': '3C675A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 07:45Z',
#      'local': '2024-03-11 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:49Z',
#      'local': '2024-03-11 08:49+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-AAX',
#     'modeS': '502D28',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'movement': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 08:10Z',
#      'local': '2024-03-11 09:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:52Z',
#      'local': '2024-03-11 08:52+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1930',
#    'callSign': 'DLH2X',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTime': {'utc': '2024-03-11 08:05Z',
#      'local': '2024-03-11 09:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:58Z',
#      'local': '2024-03-11 08:58+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1102',
#    'callSign': 'NOZ2XM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-NII', 'modeS': '47945C', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'movement': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:03Z',
#      'local': '2024-03-11 09:03+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR1434',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HEPG', 'modeS': '3991E6', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'movement': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:07Z',
#      'local': '2024-03-11 09:07+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 163',
#    'callSign': 'RYR11EH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUN', 'modeS': '4D234D', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg'},
#     'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:10Z',
#      'local': '2024-03-11 09:10+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9471',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LQB',
#     'modeS': '4D00D6',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'movement': {'airport': {'name': 'Unknown'},
#     'scheduledTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'UAG 27G',
#    'callSign': 'UAG27G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'airline': {'name': 'UAG'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 08:40Z',
#      'local': '2024-03-11 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:17Z',
#      'local': '2024-03-11 09:17+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:22Z',
#      'local': '2024-03-11 09:22+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 6892',
#    'callSign': 'EWG27ZJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EXW', 'modeS': '4D2412', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:24Z',
#      'local': '2024-03-11 09:24+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8227',
#    'callSign': 'EWG42XB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:22Z',
#      'local': '2024-03-11 09:22+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LY 2371',
#    'callSign': 'ELY2371',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4X-EKB', 'modeS': '738064', 'model': 'Boeing 737'},
#    'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1821',
#    'callSign': 'KLM69H',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-EXH', 'modeS': '4852F5', 'model': 'Embraer 175'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'movement': {'airport': {'icao': 'LTFM', 'iata': 'IST', 'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:27Z',
#      'local': '2024-03-11 09:27+01:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1721',
#    'callSign': 'THY8VN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-LOB', 'modeS': '4BB1E2', 'model': 'Airbus A330'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'movement': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-11 08:40Z',
#      'local': '2024-03-11 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:30Z',
#      'local': '2024-03-11 09:30+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 332',
#    'callSign': 'EIN3JE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-GAL', 'modeS': '4CA836', 'model': 'Airbus A320'},
#    'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#   {'movement': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'callSign': 'RYR23SD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EXE', 'modeS': '4CAA60', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:43Z',
#      'local': '2024-03-11 09:43+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5262',
#    'callSign': 'EJU5191',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'scheduledTime': {'utc': '2024-03-11 08:50Z',
#      'local': '2024-03-11 09:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2199',
#    'callSign': 'EZY73FB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-UZHO', 'modeS': '40756D', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:48Z',
#      'local': '2024-03-11 09:48+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 08:50Z',
#      'local': '2024-03-11 09:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:51Z',
#      'local': '2024-03-11 09:51+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:57Z',
#      'local': '2024-03-11 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2601',
#    'callSign': 'EZY13PJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-UZHK',
#     'modeS': '40756A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 09:10Z',
#      'local': '2024-03-11 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:53Z',
#      'local': '2024-03-11 09:53+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 990',
#    'callSign': 'BAW990',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUPG', 'modeS': '400877', 'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 8001',
#    'callSign': 'GWI8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'movement': {'airport': {'icao': 'LFST',
#      'iata': 'SXB',
#      'name': 'Strasbourg'},
#     'scheduledTime': {'utc': '2024-03-11 09:25Z',
#      'local': '2024-03-11 10:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'V7 2596',
#    'callSign': 'VOE2596',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NPB', 'modeS': '346649', 'model': 'Airbus A320'},
#    'airline': {'name': 'Volotea', 'iata': 'V7', 'icao': 'VOE'}},
#   {'movement': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:57Z',
#      'local': '2024-03-11 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8059',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:58Z',
#      'local': '2024-03-11 09:58+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1882',
#    'callSign': 'VLG1882',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-LOC', 'modeS': '344157', 'model': 'Airbus A320'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 176',
#    'callSign': 'DLH4MW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISW',
#     'modeS': '3C6677',
#     'model': 'Airbus A321-200'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-11 09:02Z',
#      'local': '2024-03-11 10:02+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:02Z',
#      'local': '2024-03-11 10:02+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 9RX',
#    'callSign': 'GWI9RX',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'movement': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:02Z',
#      'local': '2024-03-11 10:02+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 976',
#    'callSign': 'SWR2HD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JCA',
#     'modeS': '4B17F8',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'movement': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:03Z',
#      'local': '2024-03-11 10:03+01:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 145',
#    'callSign': 'RYR300Q',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QBF', 'modeS': '4D2275', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'GMMX',
#      'iata': 'RAK',
#      'name': 'Marrakech'},
#     'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 5475',
#    'callSign': 'RYR92MP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IGE',
#     'modeS': '4CADC2',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 09:06Z',
#      'local': '2024-03-11 10:06+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:06Z',
#      'local': '2024-03-11 10:06+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 9XL',
#    'callSign': 'GWI9XL',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'movement': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'scheduledTime': {'utc': '2024-03-11 09:20Z',
#      'local': '2024-03-11 10:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:06Z',
#      'local': '2024-03-11 10:06+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:57Z',
#      'local': '2024-03-11 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'S02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5058',
#    'callSign': 'EZY13PJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 09:10Z',
#      'local': '2024-03-11 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:08Z',
#      'local': '2024-03-11 10:08+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1934',
#    'callSign': 'DLH5T',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINT',
#     'modeS': '3C65D4',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:09Z',
#      'local': '2024-03-11 10:09+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8041',
#    'callSign': 'GWI9XL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-11 09:30Z',
#      'local': '2024-03-11 10:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:13Z',
#      'local': '2024-03-11 10:13+01:00'},
#     'terminal': '1',
#     'gate': 'S02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5282',
#    'callSign': 'EJU96JH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQW', 'modeS': '440171', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LIRP', 'iata': 'PSA', 'name': 'Pisa'},
#     'scheduledTime': {'utc': '2024-03-11 09:10Z',
#      'local': '2024-03-11 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:15Z',
#      'local': '2024-03-11 10:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 9955',
#    'callSign': 'RYR904A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAU', 'modeS': '4D2269', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EPWA', 'iata': 'WAW', 'name': 'Warsaw'},
#     'scheduledTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:17Z',
#      'local': '2024-03-11 10:17+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 387',
#    'callSign': 'LOT7AE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-LIN', 'modeS': '48AD0D', 'model': 'Embraer 175'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'movement': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:19Z',
#      'local': '2024-03-11 10:19+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 225',
#    'callSign': 'AUA225S',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LBD', 'modeS': '440039', 'model': 'Airbus A321'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'movement': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:24Z',
#      'local': '2024-03-11 10:24+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1143',
#    'callSign': 'RYR52AR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EVJ', 'modeS': '4CA9D2', 'model': 'Boeing 737'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 09:40Z',
#      'local': '2024-03-11 10:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:26Z',
#      'local': '2024-03-11 10:26+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:34Z',
#      'local': '2024-03-11 10:34+01:00'},
#     'terminal': '1',
#     'gate': 'S02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5188',
#    'callSign': 'EJU68JD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVR', 'modeS': '440096', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik'},
#     'scheduledTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:29Z',
#      'local': '2024-03-11 10:29+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'OG 700',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PPC', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#   {'movement': {'airport': {'icao': 'LTFJ', 'iata': 'SAW', 'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-11 09:55Z',
#      'local': '2024-03-11 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:38Z',
#      'local': '2024-03-11 10:38+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 977',
#    'callSign': 'PGT5ML',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-RBF',
#     'modeS': '4BC846',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'movement': {'airport': {'icao': 'LPFR', 'iata': 'FAO', 'name': 'Faro'},
#     'scheduledTime': {'utc': '2024-03-11 09:45Z',
#      'local': '2024-03-11 10:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:36Z',
#      'local': '2024-03-11 10:36+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:37Z',
#      'local': '2024-03-11 10:37+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 254',
#    'callSign': 'RYR12DR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IJD',
#     'modeS': '4CAE54',
#     'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik'},
#     'scheduledTime': {'utc': '2024-03-11 09:37Z',
#      'local': '2024-03-11 10:37+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:37Z',
#      'local': '2024-03-11 10:37+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:37Z',
#      'local': '2024-03-11 10:37+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'FPY 3',
#    'callSign': 'FPY3',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PPC',
#     'modeS': '4CC561',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'FPY'}},
#   {'movement': {'airport': {'icao': 'LTFM', 'iata': 'IST', 'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:38Z',
#      'local': '2024-03-11 10:38+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1729',
#    'callSign': 'THY1729',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-JYM', 'modeS': '4BAB2D', 'model': 'Boeing 737'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'movement': {'airport': {'name': 'Unknown'},
#     'scheduledTime': {'utc': '2024-03-11 09:39Z',
#      'local': '2024-03-11 10:39+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:39Z',
#      'local': '2024-03-11 10:39+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'PBB 16',
#    'callSign': 'PBB16',
#    'status': 'Approaching',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-HBBY',
#     'modeS': '3DD576',
#     'model': 'Eurocopter EC135'},
#    'airline': {'name': 'PBB'}},
#   {'movement': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTime': {'utc': '2024-03-11 09:45Z',
#      'local': '2024-03-11 10:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:40Z',
#      'local': '2024-03-11 10:40+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 820',
#    'callSign': 'AEE8RB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SX-NAD',
#     'modeS': '46B824',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'movement': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'scheduledTime': {'utc': '2024-03-11 09:55Z',
#      'local': '2024-03-11 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:41Z',
#      'local': '2024-03-11 10:41+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2933',
#    'callSign': 'EZY80CB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-UZHM',
#     'modeS': '407567',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-11 09:55Z',
#      'local': '2024-03-11 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:43Z',
#      'local': '2024-03-11 10:43+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 3676',
#    'callSign': 'IBS36YR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-OAU',
#     'modeS': '347501',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'movement': {'airport': {'icao': 'LBSF', 'iata': 'SOF', 'name': 'Sofia'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:47Z',
#      'local': '2024-03-11 10:47+01:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1149',
#    'callSign': 'RYR4EB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QEU', 'modeS': '4D23FD', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'DTTA', 'iata': 'TUN', 'name': 'Tunis'},
#     'scheduledTime': {'utc': '2024-03-11 10:15Z',
#      'local': '2024-03-11 11:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:51Z',
#      'local': '2024-03-11 10:51+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BJ 232',
#    'callSign': 'LBT232',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TS-INC', 'modeS': '02A1A2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Nouvelair Tunisie', 'iata': 'BJ', 'icao': 'LBT'}},
#   {'movement': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:53Z',
#      'local': '2024-03-11 10:53+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 2677',
#    'callSign': 'SAS2677',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-SIY',
#     'modeS': '4CADDA',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 09:55Z',
#      'local': '2024-03-11 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:56Z',
#      'local': '2024-03-11 10:56+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 178',
#    'callSign': 'DLH8HR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUM', 'modeS': '3C66AD', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:59Z',
#      'local': '2024-03-11 10:59+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TV 720',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Tibet', 'iata': 'TV', 'icao': 'TBA'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:03Z',
#      'local': '2024-03-11 11:03+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:09Z',
#      'local': '2024-03-11 11:09+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1823',
#    'callSign': 'KLM95E',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'movement': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTime': {'utc': '2024-03-11 10:20Z',
#      'local': '2024-03-11 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:06Z',
#      'local': '2024-03-11 11:06+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:12Z',
#      'local': '2024-03-11 11:12+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5007',
#    'callSign': 'PGT99EZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NCF',
#     'modeS': '4BB866',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'movement': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'TR 720',
#    'callSign': 'TGW720',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Scoot', 'iata': 'TR', 'icao': 'TGW'}},
#   {'movement': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:10Z',
#      'local': '2024-03-11 11:10+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2581',
#    'callSign': 'BEL8CE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'movement': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:13Z',
#      'local': '2024-03-11 11:13+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8491',
#    'callSign': 'CFE76JZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYT', 'modeS': '406B6D', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:26Z',
#      'local': '2024-03-11 11:26+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5144',
#    'callSign': 'EJU70ZR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:31Z',
#      'local': '2024-03-11 11:31+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 4505',
#    'callSign': 'NSZ4505',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RXB', 'modeS': '4ACB02', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'movement': {'airport': {'icao': 'ORER', 'iata': 'EBL', 'name': 'Arbil'},
#     'scheduledTime': {'utc': '2024-03-11 10:30Z',
#      'local': '2024-03-11 11:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:35Z',
#      'local': '2024-03-11 11:35+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:42Z',
#      'local': '2024-03-11 11:42+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'UD 445',
#    'callSign': 'UBD445',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LZ-BHM', 'modeS': '452087', 'model': 'Airbus A320'},
#    'airline': {'name': 'UR', 'iata': 'UD', 'icao': 'UBD'}},
#   {'movement': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTime': {'utc': '2024-03-11 10:20Z',
#      'local': '2024-03-11 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:39Z',
#      'local': '2024-03-11 11:39+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:45Z',
#      'local': '2024-03-11 11:45+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5182',
#    'callSign': 'EJU39TE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 11:00Z',
#      'local': '2024-03-11 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:43Z',
#      'local': '2024-03-11 11:43+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:44Z',
#      'local': '2024-03-11 11:44+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 3302',
#    'callSign': 'NSZ3302',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-NIG', 'modeS': '4794F2', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'movement': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 10:30Z',
#      'local': '2024-03-11 11:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:47Z',
#      'local': '2024-03-11 11:47+01:00'},
#     'terminal': '1',
# ...
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZA', 'modeS': '3C6741', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EPWA', 'iata': 'WAW', 'name': 'Warsaw'},
#     'scheduledTime': {'utc': '2024-03-11 16:55Z',
#      'local': '2024-03-11 17:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 16:55Z',
#      'local': '2024-03-11 17:55+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 389',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'movement': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTime': {'utc': '2024-03-11 16:55Z',
#      'local': '2024-03-11 17:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:01Z',
#      'local': '2024-03-11 18:01+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 41',
#    'callSign': 'RYR9JF',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QBO', 'modeS': '4D221D', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 17:10Z',
#      'local': '2024-03-11 18:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:10Z',
#      'local': '2024-03-11 18:10+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1948',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUH',
#     'modeS': '3C66A8',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LEVC', 'iata': 'VLC', 'name': 'Valencia'},
#     'scheduledTime': {'utc': '2024-03-11 17:00Z',
#      'local': '2024-03-11 18:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:16Z',
#      'local': '2024-03-11 18:16+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5104',
#    'callSign': 'EJU96EG',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJW', 'modeS': '44093E', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-11 17:45Z',
#      'local': '2024-03-11 18:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:25Z',
#      'local': '2024-03-11 18:25+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5124',
#    'callSign': 'EZY5124',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-11 17:50Z',
#      'local': '2024-03-11 18:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:28Z',
#      'local': '2024-03-11 18:28+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 336',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-CVB', 'modeS': '4CA15D', 'model': 'Airbus A320'},
#    'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#   {'movement': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-11 17:25Z',
#      'local': '2024-03-11 18:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:54Z',
#      'local': '2024-03-11 18:54+01:00'},
#     'terminal': '1',
#     'gate': 'A10',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1435',
#    'status': 'Delayed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LXC', 'modeS': '461F64', 'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'movement': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 986',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 194',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZG', 'modeS': '3C6747', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 982',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JCB',
#     'modeS': '4B17F9',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'movement': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:55Z',
#      'local': '2024-03-11 18:55+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 235',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LXC', 'modeS': '44022D', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'movement': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 17:45Z',
#      'local': '2024-03-11 18:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 17:59Z',
#      'local': '2024-03-11 18:59+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9044',
#    'callSign': 'GWI5CN',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWM', 'modeS': '3C5EED', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 213',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A220-300'},
#    'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#   {'movement': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 3672',
#    'callSign': 'IBS36HC',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-OAU',
#     'modeS': '347501',
#     'model': 'Airbus A321-100'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'movement': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IB 3672',
#    'status': 'Expected',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#   {'movement': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:00Z',
#      'local': '2024-03-11 19:00+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKP', 'modeS': '440018', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-11 18:10Z',
#      'local': '2024-03-11 19:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:10Z',
#      'local': '2024-03-11 19:10+01:00'},
#     'terminal': '1',
#     'gate': 'A17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 18',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWU', 'modeS': '3C56F5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 18:10Z',
#      'local': '2024-03-11 19:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:10Z',
#      'local': '2024-03-11 19:10+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1950',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISI', 'modeS': '3C6669', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-11 18:15Z',
#      'local': '2024-03-11 19:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:15Z',
#      'local': '2024-03-11 19:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 125',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 18:30Z',
#      'local': '2024-03-11 19:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:30Z',
#      'local': '2024-03-11 19:30+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5122',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTime': {'utc': '2024-03-11 18:35Z',
#      'local': '2024-03-11 19:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:35Z',
#      'local': '2024-03-11 19:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1108',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'movement': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTime': {'utc': '2024-03-11 18:40Z',
#      'local': '2024-03-11 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:40Z',
#      'local': '2024-03-11 19:40+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 233',
#    'callSign': 'RYR233',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IFZ',
#     'modeS': '4CADC0',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#     'scheduledTime': {'utc': '2024-03-11 18:40Z',
#      'local': '2024-03-11 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:40Z',
#      'local': '2024-03-11 19:40+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3391',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAO', 'modeS': '4D222E', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 18:50Z',
#      'local': '2024-03-11 19:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:50Z',
#      'local': '2024-03-11 19:50+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 978',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JCL',
#     'modeS': '4B1803',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 18:55Z',
#      'local': '2024-03-11 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:55Z',
#      'local': '2024-03-11 19:55+01:00'},
#     'terminal': '2',
#     'gate': 'Z33',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 217',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QCW', 'modeS': '4D2258', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 18:55Z',
#      'local': '2024-03-11 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 18:55Z',
#      'local': '2024-03-11 19:55+01:00'},
#     'terminal': '1',
#     'gate': 'S02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 198',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRT', 'modeS': '3C6654', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]}
