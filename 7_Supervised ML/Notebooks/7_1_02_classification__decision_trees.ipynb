# %% [markdown]
# # Titanic 2: Decision Trees
#
# **Dataset variables:**
#
# *   survival -->	Whether a passenger survived or not
# *   pclass -->	Ticket class (1 = 1st, 2 = 2nd, 3 = 3rd)
# *   sex -->	Sex
# *   Age -->	Age in years
# *   sibsp -->	# of siblings / spouses aboard the Titanic
# *   parch -->	# of parents / children aboard the Titanic
# *   ticket -->	Ticket number
# *   fare -->	Passenger fare
# *   cabin -->	Cabin number
# *   embarked -->	Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)

# %% [markdown]
# ## 1. Read the data

# %%
import pandas as pd

url = "https://drive.google.com/file/d/1g3uhw_y3tboRm2eYDPfUzXXsw8IOYDCy/view?usp=sharing"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]


data = pd.read_csv(path)
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## 2. Define X and y

# %%
X = data.drop(columns=["PassengerId", "Name", "Ticket"])
y = X.pop("Survived")

# %% [markdown]
# ## 3. Data Splitting (Train - Test)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=31416)

# %% [markdown]
# ## 4. Implement a Decision Tree
#
# A Decision Tree is one of the simplest Machine Learning models. To implement it, we need to first:
#
# - Import it from the appropriate submodule of Scikit-Learn.
# - Initialize it.
# - Fit it.

# %%
# 1. import the model
from sklearn.tree import DecisionTreeClassifier

# 2. initialize the model (optional: give some parameters)
my_tree = DecisionTreeClassifier()

# 3. fit the model to the train data
my_tree.fit(X=X_train, y=y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24500\2935659025.py in ?()
#       4 # 2. initialize the model (optional: give some parameters)
#       5 my_tree = DecisionTreeClassifier()
#       6
#       7 # 3. fit the model to the train data
# ----> 8 my_tree.fit(X=X_train, y=y_train)
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#     955         self : DecisionTreeClassifier
#     956             Fitted estimator.
#     957         """
#     958
# --> 959         super()._fit(
#     960             X,
#     961             y,
#     962             sample_weight=sample_weight,
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     238             check_X_params = dict(
#     239                 dtype=DTYPE, accept_sparse="csc", force_all_finite=False
#     240             )
#     241             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 242             X, y = self._validate_data(
#     243                 X, y, validate_separately=(check_X_params, check_y_params)
#     244             )
#     245
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     612                 # :(
#     613                 check_X_params, check_y_params = validate_separately
#     614                 if "estimator" not in check_X_params:
#     615                     check_X_params = {**default_check_params, **check_X_params}
# --> 616                 X = check_array(X, input_name="X", **check_X_params)
#     617                 if "estimator" not in check_y_params:
#     618                     check_y_params = {**default_check_params, **check_y_params}
#     619                 y = check_array(y, input_name="y", **check_y_params)
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'male'

# %% [markdown]
# **We got an error**: the model cannot deal with categorical features. We will soon learn to encode them as numbers, but our approach should always be to quickly complete the task  first, and iterate to improve it later. This is the reason why we will simply start by dropping the categorical features.

# %% [markdown]
# ## 5. Select only numerical features

# %%
# another option: X_num = X.drop(columns=["Sex", "Cabin", "Embarked"])
X_num = X.select_dtypes(include="number")

# %%
X_num
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3   NaN      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# ### 5.1. Train-test split
#
# Since we created a new dataframe without the categorical features, we need to create our test and train sets again.

# %%
X_num_train, X_num_test, y_train, y_test = train_test_split(X_num, y, test_size=0.2, random_state=123)

# %% [markdown]
# ### 5.2. Implement a Decision Tree (numerical features)

# %%
# 1. import the model
from sklearn.tree import DecisionTreeClassifier

# 2. initialize the model (optional: give some parameters)
my_tree = DecisionTreeClassifier()

# 3. fit the model to the train data
my_tree.fit(X=X_num_train, y=y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Another error**: the model cannot deal with missing data. Let's fix it.

# %% [markdown]
# ## 6. Dealing with missing data
#
# We will use the `SimpleImputer()` with its default values. It will replace any missing value with the mean of the column it belongs to.

# %% [markdown]
# Simple imputer allows these strategies:
# - mean (default),
# - median,
# - most frequent,
# - constant.
#
# For more details, look here: https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# Follow this approach for different types of estimators:
# 1. initialize,
# 2. use fit on the **train** set,
# 3. use transform on the **train** set,
# 4. use transform on the **test** set.
#
# It is possible to combine steps 2 and 3 and use fit_transform instead.

# %%
# 1. initialize
my_imputer = SimpleImputer().set_output(transform='pandas')

# %%
# 2. use fit on the train set
my_imputer.fit(X_num_train)
# Out:
# SimpleImputer()

# %%
# 3. use transform on the train set
X_num_imputed_train = my_imputer.transform(X_num_train)

# %%
X_num_imputed_train.isnull().sum()
# Out:
# Pclass    0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %% [markdown]
# NO DATA SNOOPING!

# %% [markdown]
# We will implement the 4th step in 7.1.

# %% [markdown]
# ### 6.1. Implement a Decision Tree (numerical features + missing values imputed)

# %%
# 1. import the model
from sklearn.tree import DecisionTreeClassifier

# 2. initialize the model (optional: give some parameters)
my_tree = DecisionTreeClassifier()

# 3. fit the model to the train data
my_tree.fit(X = X_num_imputed_train,
            y = y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### 6.2. Make predictions and check accuracy on the train set

# %%
# make predictions
y_pred_tree_train = my_tree.predict(X_num_imputed_train)

# %%
# Check accuracy on the train set
from sklearn.metrics import accuracy_score

accuracy_score(y_true = y_train,
               y_pred = y_pred_tree_train
              )
# Out:
# 0.9564606741573034

# %% [markdown]
# The model seems to work REALLY well. Suspiciously well, even. Remember that the model has been trained using the train set and we have now checked its accuracy on the very same train set. The real evaluation will come from the test set.

# %% [markdown]
# ## 7. Check accuracy for the test set
#
# Is the model able to generalize? Is it able to make predictions on data it has not "seen" before?

# %% [markdown]
# ### 7.1. Transform the test set
#
# The test set already contains only numerical features, but we still need to impute the missing values with the "imputer" we already created and fitted on the train set.
#
# Remember: transformers only have to be fitted to the train set. Then, they are used to transform both the train and the test set.

# %%
# impute NaN's to test set
X_num_imputed_test = my_imputer.transform(X_num_test)

# %% [markdown]
# ### 7.2. Make predictions on the test set

# %%
y_pred_tree_test = my_tree.predict(X_num_imputed_test)

# %% [markdown]
# ### 7.3. Check accuracy score on the test set

# %%
accuracy_score(y_true = y_test,
               y_pred = y_pred_tree_test
              )
# Out:
# 0.6536312849162011

# %% [markdown]
# This accuracy is even lower than some of our intuition-based models...
#
# Our model has a **very high variance**: the difference between train and test set is huge. We can also say that our model suffers from **overfitting**: it has captured patterns in the training set that were not present in the testing set (they were mere "noise").
#
# We will need to improve the model.

# %% [markdown]
# ## 8. Plotting the Decision Tree
#
# A Decision Tree is a succession of rules that split the dataset based on the variables that better predict the target. This tree, with its rules, can be visualized in a diagram:

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(64, 32))

plot_tree(
     my_tree,
     filled=True,
     rounded=True,
     class_names=['Not Survived','Survived'],
     feature_names=X_num.columns.to_list()
     );

# %% [markdown]
# Our current tree is too big to distinguish what's going on. It has dozens, maybe hundreds of rules. In other words, our model is **very complex**, which is a common characteristic of models that suffer from overfitting.
#
# To reduce the complexity (the size) of the tree and prevent overfitting, we can play with the hyperparameters of the tree. It's a process known as "pruning" the tree.

# %% [markdown]
# ### **Exercise 1**: Pruning the tree
#
# 1. Tweak the parameters `max_depth` and `min_samples_leaf` of the decision tree, based on the Scikit-Learn documentation and the Statquest videos you watched following the Learning Platform.
# 2. Try to make the tree smaller.
# 3. Visualize again the tree.
# 4. Check the performance of your "small tree" on the train & test sets.

# %%
# your code here

# %% [markdown]
# ## **Your challenge**
#
# In a new notebook, apply everything you have learned here to the Housing project.

# %%
# !pip install graphviz
# !pip install dtreeviz
# Out:
# Requirement already satisfied: graphviz in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (0.20.3)
# Requirement already satisfied: dtreeviz in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (2.1.4)
# Requirement already satisfied: numpy in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (3.8.0)
# Requirement already satisfied: colour in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from dtreeviz) (8.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pandas->dtreeviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pytest->dtreeviz) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pytest->dtreeviz) (1.2.0)
# Requirement already satisfied: tomli>=1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pytest->dtreeviz) (2.0.1)
# Requirement already satisfied: colorama in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from scikit-learn->dtreeviz) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from scikit-learn->dtreeviz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\marvin\miniconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import dtreeviz

viz = dtreeviz.model(my_tree,
                     X_train=X_num_imputed_train,
                     y_train=y_train,
                     feature_names=X_num_imputed_train.columns,
                     class_names=["Not Survived", "Survived"])

v = viz.view()
v.save("tree.svg")
# Out:
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\subprocess.py:1456, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1455 try:
# -> 1456     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1457                              # no special security
#    1458                              None, None,
#    1459                              int(not close_fds),
#    1460                              creationflags,
#    1461                              env,
#    1462                              cwd,
#    1463                              startupinfo)
#    1464 finally:
#    1465     # Child is launched. Close the parent's copy of those pipe
#    1466     # handles that only the child should have open.  You need
#    (...)
#    1469     # pipe will not close when the child process exits and the
#    1470     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] Das System kann die angegebene Datei nicht finden
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[48], line 10
#       3 viz = dtreeviz.model(my_tree,
#       4                      X_train=X_num_imputed_train,
#       5                      y_train=y_train,
#       6                      feature_names=X_num_imputed_train.columns,
#       7                      class_names=["Not Survived", "Survived"])
#       9 v = viz.view()
# ---> 10 v.save("tree.svg")
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\dtreeviz\utils.py:294, in DTreeVizRender.save(self, filename)
#     292     graphviz.backend.run(cmd, capture_output=True, check=True, quiet=False)
#     293 else:
# --> 294     graphviz.backend.execute.run_check(cmd, capture_output=True, check=True, quiet=False)
#     296 if filename.endswith(".svg"):
#     297     # now merge in referenced SVG images to make all-in-one file
#     298     with open(filename, encoding='UTF-8') as f:
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH

# %%
viz
