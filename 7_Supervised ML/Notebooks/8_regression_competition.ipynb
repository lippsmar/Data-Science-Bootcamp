# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_regression, RFECV, SelectFromModel

# %%
data = pd.read_csv(r"C:\Users\Marvin\Documents\WBS\Data-Science-Bootcamp\7_Supervised ML\Data\housing_iteration_6_regression\housing_iteration_6_regression.csv")

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
X = data.drop(columns=['Id']).copy()
y = X.pop("SalePrice")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# Select the numerical columns from X
X_num = X_train.select_dtypes(include="number").copy()

# Select the categorical columns from X
X_cat = X_train.select_dtypes(exclude="number").copy()

# %% [markdown]
# Pipelines

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

num_pipe = make_pipeline(
    SimpleImputer()
)

ordinal_cols_names = ["LotShape", "Utilities", "ExterQual", 
                      "ExterCond", "BsmtQual", "BsmtCond", 
                      "BsmtExposure", "BsmtFinType1", "BsmtFinType2", 
                      "HeatingQC", "KitchenQual", "FireplaceQu", 
                      "GarageQual", "GarageCond", "PoolQC"]
ordinal_cols = X_cat.columns.get_indexer(ordinal_cols_names)

non_ordinal_cols_names = [col for col in X_cat.columns if col not in ordinal_cols_names]
onehot_cols = X_cat.columns.get_indexer(non_ordinal_cols_names)

ordinal_rankings = [["NA", "IR3", "IR2","IR1", "Reg"],
                    ["NA", "ELO", "NoSeWa", "NoSewr", "AllPub"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "No", "Mn", "Av", "Gd"],
                    ["NA", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"],
                    ["NA", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],
                    ["NA", "Fa", "TA", "Gd", "Ex"]] 

cat_preprocessor = make_column_transformer(
    (OrdinalEncoder(categories=ordinal_rankings), ordinal_cols),
    (OneHotEncoder(drop="first", sparse=False, handle_unknown="ignore"), onehot_cols )
)

cat_pipe = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"), # play with NA or N_A 
    cat_preprocessor)

# final preprocessor

preprocessor = make_column_transformer(
    (num_pipe, X_num.columns),
    (cat_pipe, X_cat.columns)
)

# Definition des Random Forest Regressors
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Erstellen der Pipeline, die Vorverarbeitung und Modell kombiniert
rf_pipeline = make_pipeline(preprocessor,StandardScaler(), rf_regressor)

# Training des Modells
rf_pipeline.fit(X_train, y_train)
# Out:
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'B...
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=42))])

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

gbr = GradientBoostingRegressor(n_estimators=100, 
                                learning_rate=0.1, 
                                max_depth=3, 
                                min_samples_split=2, 
                                min_samples_leaf=1)

gbr_pipeline = make_pipeline(preprocessor, gbr)

gbr_pipeline.fit(X_train, y_train)
# Out:
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'B...
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('gradientboostingregressor', GradientBoostingRegressor())])

# %% [markdown]
# Making Predictions

# %%
rfr_pred = rf_pipeline.predict(X_test)
gbr_pred = gbr_pipeline.predict(X_test)
# Out:
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [13, 20] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [13, 20] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
rfr_r2 = r2_score(y_test, rfr_pred)
gbr_r2 = r2_score(y_test, gbr_pred)

performances = pd.DataFrame({'rfr': rfr_r2,
                             'gbr': gbr_r2},
                            index=['full pipes'])

performances
# Out:
#                 rfr       gbr
# full pipes  0.87558  0.904484

# %% [markdown]
# Feature Selection

# %%
X_num
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 318           60         90.0     9900            7            5       1993
# 580           20          NaN    14585            6            6       1960
# 961           60          NaN    12227            6            7       1977
# 78            90         72.0    10778            4            5       1968
# 5             50         85.0    14115            5            5       1993
# ...          ...          ...      ...          ...          ...        ...
# 1041          60          NaN     9130            6            8       1966
# 1122          20          NaN     8926            4            3       1956
# 1346          20          NaN    20781            7            7       1968
# 1406          85         70.0     8445            5            7       1972
# 1389          50         60.0     6000            6            6       1941
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 318           1993       256.0         987           0  ...         656
# 580           1987        85.0         594         219  ...         572
# 961           1995       424.0         896           0  ...         619
# 78            1968         0.0           0           0  ...           0
# 5             1995         0.0         732           0  ...         480
# ...            ...         ...         ...         ...  ...         ...
# 1041          2000       252.0         400          64  ...         484
# 1122          1956         0.0           0           0  ...         288
# 1346          2003         0.0         297          68  ...         508
# 1406          2007         0.0         656           0  ...         396
# 1389          1950         0.0         375           0  ...         440
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 318          340           60            144          0            0
# 580          216          110              0          0            0
# 961          550          282              0          0            0
# 78             0            0              0          0            0
# 5             40           30              0        320            0
# ...          ...          ...            ...        ...          ...
# 1041           0           40              0          0            0
# 1122          64            0              0          0          160
# 1346           0           80              0        290            0
# 1406          58            0              0          0            0
# 1389           0            0              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold
# 318          0        0       4    2009
# 580          0        0       6    2007
# 961          0        0       7    2008
# 78           0        0       4    2010
# 5            0      700      10    2009
# ...        ...      ...     ...     ...
# 1041         0        0       7    2008
# 1122         0        0      10    2009
# 1346         0        0       6    2006
# 1406         0        0       3    2009
# 1389         0        0       3    2007
#
# [1168 rows x 36 columns]

# %%
range_var_df = (pd.DataFrame({
                'Range': X_num.max() - X_num.min(),
                'Variance': X_num.var()})
                .sort_values(by='Variance'))

# %%
range_var_df.tail()
# Out:
#                 Range      Variance
# TotalBsmtSF    6110.0  2.008526e+05
# BsmtFinSF1     5644.0  2.169075e+05
# GrLivArea      5308.0  2.884878e+05
# MiscVal       15500.0  3.001350e+05
# LotArea      213945.0  8.858200e+07

# %%
# Initialize the scaler.
my_scaler = MinMaxScaler().set_output(transform="pandas")

# Fit the scaler to X_train and transform the values.
X_num_scaled = my_scaler.fit_transform(X_num)

# %%
(
  pd.DataFrame({
  'Range': X_num_scaled.max() - X_num_scaled.min(),
  'Variance': X_num_scaled.var()})
  .sort_values(by='Variance')
)
# Out:
#                Range  Variance
# MiscVal          1.0  0.001249
# LotArea          1.0  0.001935
# 3SsnPorch        1.0  0.003677
# PoolArea         1.0  0.003701
# TotalBsmtSF      1.0  0.005380
# LotFrontage      1.0  0.006315
# BsmtFinSF1       1.0  0.006809
# 1stFlrSF         1.0  0.008265
# LowQualFinSF     1.0  0.008288
# GrLivArea        1.0  0.010239
# BedroomAbvGr     1.0  0.010801
# EnclosedPorch    1.0  0.011842
# BsmtFinSF2       1.0  0.012533
# BsmtHalfBath     1.0  0.012622
# ScreenPorch      1.0  0.013162
# OpenPorchSF      1.0  0.014415
# TotRmsAbvGrd     1.0  0.018829
# OverallCond      1.0  0.019947
# WoodDeckSF       1.0  0.022274
# GarageArea       1.0  0.022437
# MasVnrArea       1.0  0.023257
# OverallQual      1.0  0.024277
# BsmtFullBath     1.0  0.030422
# FullBath         1.0  0.033741
# GarageCars       1.0  0.034779
# BsmtUnfSF        1.0  0.036001
# 2ndFlrSF         1.0  0.044810
# Fireplaces       1.0  0.045039
# KitchenAbvGr     1.0  0.047232
# YearBuilt        1.0  0.048520
# GarageYrBlt      1.0  0.051169
# MoSold           1.0  0.059727
# MSSubClass       1.0  0.062391
# HalfBath         1.0  0.063140
# YrSold           1.0  0.111059
# YearRemodAdd     1.0  0.117177

# %%
selector = VarianceThreshold(threshold=0.01)

X_num_var = selector.fit_transform(X_num_scaled)

# %%
print("shape before:", X_num_scaled.shape)
print("shape after:", X_num_var.shape)
# Out:
# shape before: (1168, 36)
# shape after: (1168, 27)

# %%
# Scale the test set
X_test_num = X_test.select_dtypes(include="number").copy()
X_test_scaled = my_scaler.transform(X_test_num)

# Apply the variance threshold to the scaled test set
X_test_var = selector.transform(X_test_scaled)

# %%
# rfr
var_rfr = rf_pipeline
var_rfr.fit(X_num_var, y_train)
var_rfr_pred = var_rfr.predict(X_test_var)

# gbr
var_gbr = gbr_pipeline
var_gbr.fit(X_num_var, y_train)
var_gbr_pred = var_gbr.predict(X_test_var)

performances.loc["varThreshold_0_01", "rfr"] = r2_score(y_test, var_rfr_pred)
performances.loc["varThreshold_0_01", "gbr"] = r2_score(y_test, var_gbr_pred)

performances
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\utils\__init__.py:423, in _get_column_indices(X, key)
#     422 try:
# --> 423     all_columns = X.columns
#     424 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 3
#       1 # rfr
#       2 var_rfr = rf_pipeline
# ----> 3 var_rfr.fit(X_num_var, y_train)
#       4 var_rfr_pred = var_rfr.predict(X_test_var)
#       6 # gbr
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
#     392 Fit all the transformers one after the other and transform the
#    (...)
#     413     Pipeline with fitted steps.
#     414 """
#     415 fit_params_steps = self._check_fit_params(**fit_params)
# --> 416 Xt = self._fit(X, y, **fit_params_steps)
#     417 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     418     if self._final_estimator != "passthrough":
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\pipeline.py:370, in Pipeline._fit(self, X, y, **fit_params_steps)
#     368     cloned_transformer = clone(transformer)
#     369 # Fit or load from cache the current transformer
# --> 370 X, fitted_transformer = fit_transform_one_cached(
#     371     cloned_transformer,
#     372     X,
#     373     y,
#     374     None,
#     375     message_clsname="Pipeline",
#     376     message=self._log_message(step_idx),
#     377     **fit_params_steps[name],
#     378 )
#     379 # Replace the transformer of the step with the fitted
#     380 # transformer. This is necessary when loading the transformer
#     381 # from the cache.
#     382 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\compose\_column_transformer.py:740, in ColumnTransformer.fit_transform(self, X, y)
#     738 self._check_n_features(X, reset=True)
#     739 self._validate_transformers()
# --> 740 self._validate_column_callables(X)
#     741 self._validate_remainder(X)
#     743 result = self._fit_transform(X, y, _fit_transform_one)
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\compose\_column_transformer.py:448, in ColumnTransformer._validate_column_callables(self, X)
#     446         columns = columns(X)
#     447     all_columns.append(columns)
# --> 448     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     450 self._columns = all_columns
#     451 self._transformer_to_input_indices = transformer_to_input_indices
#
# File c:\Users\Marvin\miniconda3\envs\myenv\lib\site-packages\sklearn\utils\__init__.py:425, in _get_column_indices(X, key)
#     423     all_columns = X.columns
#     424 except AttributeError:
# --> 425     raise ValueError(
#     426         "Specifying the columns using strings is only "
#     427         "supported for pandas DataFrames"
#     428     )
#     429 if isinstance(key, str):
#     430     columns = [key]
#
# ValueError: Specifying the columns using strings is only supported for pandas DataFrames
